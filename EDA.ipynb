# %% [markdown]
# ### EDA

# %% [markdown]
# # Structure & Content Discoveries on Dataset about Obesity Levels in Mexico, Peru, and Colombia

# %% [markdown]
# ### Description
#
# This dataset include data for the estimation of obesity levels in individuals from the countries of Mexico, Peru and Colombia, based on their eating habits and physical condition. The ages of people were between the ages of 14 and 61. The infomation were colated in a 2111 by 17 tables (rows and columns respectively).
#
# The attributes related with eating habits are: Frequent consumption of high caloric food (FAVC), Frequency of consumption of vegetables (FCVC), Number of main meals (NCP), Consumption of food between meals (CAEC), Consumption of water daily (CH20), and Consumption of alcohol (CALC).
#
# The attributes related with the physical condition are: Calories consumption monitoring (SCC), Physical activity frequency (FAF), Time using technology devices (TUE), Transportation used (MTRANS), other variables obtained were: Gender, Age, Height and Weight.
#
# Finally, all data was labeled and the class variable NObesity was created with the values of: Insufficient Weight, Normal Weight, Overweight Level I, Overweight Level II, Obesity Type I, Obesity Type II and Obesity Type III, based on Equation (1) and information from WHO and Mexican Normativity. The data contains numerical data and continous data, so it can be used for analysis based on algorithms of classification, prediction, segmentation and association. Data is available in CSV format.
#
# Questions of the survey used for initial recollection of information.
#
# Questions with Possible Answers
#
# 1. What is your gender?
#     •Female •Male
#
# 2. what is your age?
#     Numeric value
#
# 3. what is your height?
#     Numeric value in meters
#
# 4. what is your weight?
#     Numeric value in kilograms
#
# 5. Has a family member suffered or suffers from overweight?
#     •Yes •No
#
# 6. Do you eat high caloric food frequently?
#     •Yes •No
#
# 7. Do you usually eat vegetables in your meals?
#     •Never •Sometimes •Always
#
# 8. How many main meals do you have daily?
#     •Between 1 y 2 •Three •More than three
#
# 9. Do you eat any food between meals?
#     •No •Sometimes •Frequently •Always
#
# 10. Do you smoke?
#     •Yes •No
#
# 11. How much water do you drink daily?
#     •Less than a liter •Between 1 and 2 L •More than 2 L
#
# 12. Do you monitor the calories you eat daily?
#     •Yes •No
#
# 13. How often do you have physical activity?
#     •I do not have •1 or 2 days •2 or 4 days •4 or 5 days
#
# 14. How much time do you use technological devices such as cell phone, videogames, television, computer and others?
#     •0–2 hours •3–5 hours •More than 5 hours
#
# 15. how often do you drink alcohol?
#     •I do not drink •Sometimes •Frequently •Always
#
# 16. Which transportation do you usually use?
#     •Automobile •Motorbike •Bike •Public Transportation •Walking

# %% [markdown]
# Import Python libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Load the dataset

# %%
dataset = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv',encoding = "utf-8")
df = pd.DataFrame(dataset)

# %% [markdown]
# ### Data Overview

# %%
#get the first 10 records
df.head(20)
# Out:
#     Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0   Female  21.0    1.62    64.0                            yes   no   2.0
# 1   Female  21.0    1.52    56.0                            yes   no   3.0
# 2     Male  23.0    1.80    77.0                            yes   no   2.0
# 3     Male  27.0    1.80    87.0                             no   no   3.0
# 4     Male  22.0    1.78    89.8                             no   no   2.0
# 5     Male  29.0    1.62    53.0                             no  yes   2.0
# 6   Female  23.0    1.50    55.0                            yes  yes   3.0
# 7     Male  22.0    1.64    53.0                             no   no   2.0
# 8     Male  24.0    1.78    64.0                            yes  yes   3.0
# 9     Male  22.0    1.72    68.0                            yes  yes   2.0
# 10    Male  26.0    1.85   105.0                            yes  yes   3.0
# ...

# %%
#get the last 10 records
df.tail(10)
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 2101  Female  25.722004  1.628470  107.218949                            yes
# 2102  Female  25.765628  1.627839  108.107360                            yes
# 2103  Female  21.016849  1.724268  133.033523                            yes
# 2104  Female  21.682367  1.732383  133.043941                            yes
# 2105  Female  21.285965  1.726920  131.335786                            yes
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# ...

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
df.count()
# Out:
# Gender                            2111
# Age                               2111
# Height                            2111
# Weight                            2111
# family_history_with_overweight    2111
# FAVC                              2111
# FCVC                              2111
# NCP                               2111
# CAEC                              2111
# SMOKE                             2111
# CH2O                              2111
# SCC                               2111
# FAF                               2111
# TUE                               2111
# CALC                              2111
# MTRANS                            2111
# NObeyesdad                        2111
# dtype: int64

# %%
def data_value_count(column):
    return df[column].value_counts()

# %%
data_value_count('Gender')
# Out:
# Male      1068
# Female    1043
# Name: Gender, dtype: int64

# %%
dataset['Gender'].value_counts()
# Out:
# Male      1068
# Female    1043
# Name: Gender, dtype: int64

# %%
df.describe(include = 'all')
# Out:
#        Gender          Age       Height       Weight  \
# count    2111  2111.000000  2111.000000  2111.000000
# unique      2          NaN          NaN          NaN
# top      Male          NaN          NaN          NaN
# freq     1068          NaN          NaN          NaN
# mean      NaN    24.312600     1.701677    86.586058
# std       NaN     6.345968     0.093305    26.191172
# min       NaN    14.000000     1.450000    39.000000
# 25%       NaN    19.947192     1.630000    65.473343
# 50%       NaN    22.777890     1.700499    83.000000
# 75%       NaN    26.000000     1.768464   107.430682
# max       NaN    61.000000     1.980000   173.000000
#
#        family_history_with_overweight  FAVC         FCVC          NCP  \
# count                            2111  2111  2111.000000  2111.000000
# unique                              2     2          NaN          NaN
# top                               yes   yes          NaN          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
# Gender                            2111 non-null object
# Age                               2111 non-null float64
# Height                            2111 non-null float64
# Weight                            2111 non-null float64
# family_history_with_overweight    2111 non-null object
# FAVC                              2111 non-null object
# FCVC                              2111 non-null float64
# NCP                               2111 non-null float64
# CAEC                              2111 non-null object
# SMOKE                             2111 non-null object
# CH2O                              2111 non-null float64
# SCC                               2111 non-null object
# FAF                               2111 non-null float64
# TUE                               2111 non-null float64
# CALC                              2111 non-null object
# ...

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# checking if a null cell exist

# %%
df.isnull()
# Out:
#       Gender    Age  Height  Weight  family_history_with_overweight   FAVC  \
# 0      False  False   False   False                           False  False
# 1      False  False   False   False                           False  False
# 2      False  False   False   False                           False  False
# 3      False  False   False   False                           False  False
# 4      False  False   False   False                           False  False
# ...      ...    ...     ...     ...                             ...    ...
# 2106   False  False   False   False                           False  False
# 2107   False  False   False   False                           False  False
# 2108   False  False   False   False                           False  False
# 2109   False  False   False   False                           False  False
# 2110   False  False   False   False                           False  False
#
# ...

# %% [markdown]
# Observation: All records cannot be viewed at once in jupyter. Below is the sum of null data cells in each attributes

# %%
pd.DataFrame(dataset.isnull().sum(), columns=["Summary of null data"])
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %% [markdown]
# Observation: No null cell in the dataset

# %% [markdown]
# checking if duplicated data exists

# %%
dataset.duplicated().sum()
# Out:
# 24

# %% [markdown]
# Observation: There are 24 duplicates in the dataset

# %%
dataset[dataset.duplicated()]
# Out:
#      Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 98   Female  21.0    1.52    42.0                             no   no   3.0
# 106  Female  25.0    1.57    55.0                             no  yes   2.0
# 174    Male  21.0    1.62    70.0                             no  yes   2.0
# 179    Male  21.0    1.62    70.0                             no  yes   2.0
# 184    Male  21.0    1.62    70.0                             no  yes   2.0
# 209  Female  22.0    1.69    65.0                            yes  yes   2.0
# 309  Female  16.0    1.66    58.0                             no   no   2.0
# 460  Female  18.0    1.62    55.0                            yes  yes   2.0
# 467    Male  22.0    1.74    75.0                            yes  yes   3.0
# 496    Male  18.0    1.72    53.0                            yes  yes   2.0
# 527  Female  21.0    1.52    42.0                             no  yes   3.0
# ...

# %% [markdown]
# View of the duplicates
# The duplicates will be retained because each record is not distinctly unique.

# %% [markdown]
# Treating Missing Values

# %%
# removing null values to avoid errors 
dataset.dropna(inplace = True)

# %%
# removing duplicated values to avoid errors 
dataset.drop_duplicates(inplace = True)

# %% [markdown]
# Calculating BMI

# %%
df['BMI'] = df['Weight']/(df['Height']**2)

# %%
df.head(10)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
# 5    Male  29.0    1.62    53.0                             no  yes   2.0
# 6  Female  23.0    1.50    55.0                            yes  yes   3.0
# 7    Male  22.0    1.64    53.0                             no   no   2.0
# 8    Male  24.0    1.78    64.0                            yes  yes   3.0
# 9    Male  22.0    1.72    68.0                            yes  yes   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# ...

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE          BMI
# count  2111.000000  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866    29.700159
# std       0.612953     0.850592     0.608927     8.011337
# min       1.000000     0.000000     0.000000    12.998685
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 18 columns):
# Gender                            2111 non-null object
# Age                               2111 non-null float64
# Height                            2111 non-null float64
# Weight                            2111 non-null float64
# family_history_with_overweight    2111 non-null object
# FAVC                              2111 non-null object
# FCVC                              2111 non-null float64
# NCP                               2111 non-null float64
# CAEC                              2111 non-null object
# SMOKE                             2111 non-null object
# CH2O                              2111 non-null float64
# SCC                               2111 non-null object
# FAF                               2111 non-null float64
# TUE                               2111 non-null float64
# CALC                              2111 non-null object
# ...

# %%
df.corr()
# Out:
#              Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# Age     1.000000 -0.025958  0.202560  0.016291 -0.043944 -0.045304 -0.144938
# Height -0.025958  1.000000  0.463136 -0.038121  0.243672  0.213376  0.294709
# Weight  0.202560  0.463136  1.000000  0.216125  0.107469  0.200575 -0.051436
# FCVC    0.016291 -0.038121  0.216125  1.000000  0.042216  0.068461  0.019939
# NCP    -0.043944  0.243672  0.107469  0.042216  1.000000  0.057088  0.129504
# CH2O   -0.045304  0.213376  0.200575  0.068461  0.057088  1.000000  0.167236
# FAF    -0.144938  0.294709 -0.051436  0.019939  0.129504  0.167236  1.000000
# TUE    -0.296931  0.051912 -0.071561 -0.101135  0.036326  0.011965  0.058562
# BMI     0.244163  0.131785  0.934806  0.263651  0.039969  0.144200 -0.177537
#
#              TUE       BMI
# Age    -0.296931  0.244163
# Height  0.051912  0.131785
# Weight -0.071561  0.934806
# FCVC   -0.101135  0.263651
# NCP     0.036326  0.039969
# CH2O    0.011965  0.144200
# ...

# %%
df.cov()
# Out:
#               Age    Height      Weight      FCVC       NCP      CH2O  \
# Age     40.271313 -0.015370   33.667180  0.055198 -0.216968 -0.176222
# Height  -0.015370  0.008706    1.131795 -0.001899  0.017689  0.012203
# Weight  33.667180  1.131795  685.977477  3.022323  2.189976  3.220031
# FCVC     0.055198 -0.001899    3.022323  0.285078  0.017537  0.022406
# NCP     -0.216968  0.017689    2.189976  0.017537  0.605344  0.027225
# CH2O    -0.176222  0.012203    3.220031  0.022406  0.027225  0.375712
# FAF     -0.782353  0.023389   -1.145898  0.009056  0.085705  0.087193
# TUE     -1.147409  0.002949   -1.141298 -0.032881  0.017210  0.004466
# BMI     12.413177  0.098508  196.146825  1.127757  0.249134  0.708106
#
#              FAF       TUE         BMI
# Age    -0.782353 -1.147409   12.413177
# Height  0.023389  0.002949    0.098508
# Weight -1.145898 -1.141298  196.146825
# FCVC    0.009056 -0.032881    1.127757
# NCP     0.085705  0.017210    0.249134
# ...

# %% [markdown]
# Virtual represention of number of Male and Female

# %%
sns.countplot(x="Gender", data=df)

# %% [markdown]
# Observation: There are more Male than Female in the dataset

# %%
frequency = range(0,3000)

# %%
sns.set(style='whitegrid')
sns.catplot(x="NObeyesdad", y="BMI",data=df, height=3, kind='bar', aspect=4)
plt.show()

# %% [markdown]
# Observation: The BMI of of each level of Nobeyesdad
# Normal_Weigth has a BMI above 20.0 but below 25.0
# Overweight_Level_I has a BMI above 25.0 but below 27.0
# Overweight_Level_II has a BMI above 25.0 but below 30.0
# Obesity_Type_I has a BMI above 30.0 but below 35.0
# Insufficient_Weigth has a BMI below 15.0
# Obesity_Type_II has a BMI above 35.0 but below 40.0
# Obesity_Type_III has a BMI above 40.0

# %%
plt.figure(figsize=(15,5))
sns.set(style='whitegrid')
graph = sns.catplot(x="NObeyesdad", hue="Gender",data=df,height=3,aspect=4,kind='count')
graph.set(ylabel="frequency")
plt.show()

# %% [markdown]
# Obeservation: Male are Female are in all levels of Obesity except that in Obesity_Type_II, no Male present and in Obesity_Type_III, no Female present in Obesity_Type_II
# Hypothesis: Male suffer from Obesity_Type_III while Female does not suffer from Obesity_Type_II

# %%
plt.figure(figsize=(5,5))
sns.set(style='whitegrid')
graph = sns.countplot(x="SMOKE", hue="Gender",data=df)
plt.show()

# %% [markdown]
# Observation: Less individual in the dataset smokes

# %%
sns.set(style='whitegrid')
graph = sns.catplot(x="SMOKE", y=frequency,hue="NObeyesdad",data=df,height=5,aspect=3, kind="bar")
graph.set(ylabel='frequency')
plt.show()

# %% [markdown]
# Obeservation: Less number of smokers are overweight or obese, but expection found in Obesity_Type_II

# %%
sns.set(style='whitegrid')
graph = sns.catplot(x="SMOKE", y=frequency,hue="NObeyesdad",col="Gender",data=df, kind='bar', height=10,aspect=1)
graph.set(ylabel='frequency')
plt.show()

# %% [markdown]
# Observation: More smokers are obesed and overweigth. Female smokers are not in category of Obesity_Type_II, while Male smokers are not in category of both Insfficient_Weight and Obesity_Type_III

# %%
sns.set(style='whitegrid')
graph = sns.catplot(x="family_history_with_overweight", y=frequency,hue="NObeyesdad", col="FAVC", row="SMOKE",data=df, kind='bar')
graph.set(ylabel="frequency")
plt.show()

# %% [markdown]
# Oberservation: People that smokes and not frequently consume high calories food also has no family history of overweight has lower obesed or overweighted individuals
# Hypothesis: Smoking is not a factor for the cause of Overweight or Obesity.

# %%
sns.set(style='whitegrid')
graph = sns.catplot(x="family_history_with_overweight", y=frequency,hue="NObeyesdad", height=5,aspect=3,data=df, kind='bar')
graph.set(ylabel='frequency')
plt.show()

# %% [markdown]
# Observation: There are more overweight and Obesity suitation in people with family history with history of overweight

# %%
sns.set(style='whitegrid')
graph = sns.catplot(x="family_history_with_overweight", y=frequency,hue="NObeyesdad", col="FAVC",data=df, kind='bar')
graph.set(ylabel='frequency')
plt.show()

# %% [markdown]
# Observation: There are more overweigthed and obesed people that have family history of overweight and frequently consume of high calories food.

# %%
sns.set(style='whitegrid')
graph = sns.catplot(x="family_history_with_overweight", y=frequency,hue="NObeyesdad", col="FAVC", row="CALC",data=df, kind='bar')
graph.set(ylabel='frequency')
plt.show()
